# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## ***`Knowing`***

# %%
Athletes=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Practice Project/Untitled folder/Tokyo olympic dataset/Athletes.xlsx")
Coaches=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Practice Project/Untitled folder/Tokyo olympic dataset/Coaches.xlsx")
EntriesGender=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Practice Project/Untitled folder/Tokyo olympic dataset/EntriesGender.xlsx")
Medals=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Practice Project/Untitled folder/Tokyo olympic dataset/Medals.xlsx")
Teams=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Practice Project/Untitled folder/Tokyo olympic dataset/Teams.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
print(Athletes.head())
print("//////////////////////////////////////////////////////////////////////////")
print(Coaches.head())
print("/////////////////////////////////////////////////////////////////////////")

print(EntriesGender.head())
print("///////////////////////////////////////////////////////////////////////")

print(Medals.head())
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball
# //////////////////////////////////////////////////////////////////////////
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN
# /////////////////////////////////////////////////////////////////////////
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# ...

# %%
Datasets=['Athletes,Coaches,EntriesGender,Medals,Teams']

# %%
print("Athletes--->  ",Athletes.shape)
print("Coaches--->  ",Coaches.shape)
print("EntriesGender--->  ",EntriesGender.shape)
print("Medals--->  ",Medals.shape)
print("Teams---> ",Teams.shape)
# Out:
# Athletes--->   (11085, 3)
# Coaches--->   (394, 4)
# EntriesGender--->   (46, 4)
# Medals--->   (93, 7)
# Teams--->  (743, 4)

# %% [markdown]
# ## ***Athletes***

# %%
Athletes.head(20)
# Out:
#                        Name                       NOC           Discipline
# 0           AALERUD Katrine                    Norway         Cycling Road
# 1               ABAD Nestor                     Spain  Artistic Gymnastics
# 2         ABAGNALE Giovanni                     Italy               Rowing
# 3            ABALDE Alberto                     Spain           Basketball
# 4             ABALDE Tamara                     Spain           Basketball
# 5                 ABALO Luc                    France             Handball
# 6              ABAROA Cesar                     Chile               Rowing
# 7             ABASS Abobakr                     Sudan             Swimming
# 8          ABBASALI Hamideh  Islamic Republic of Iran               Karate
# 9             ABBASOV Islam                Azerbaijan            Wrestling
# 10             ABBINGH Lois               Netherlands             Handball
# ...

# %%
Athletes.shape
# Out:
# (11085, 3)

# %%
Athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB

# %%
#Checking Null Values
Athletes.isnull().sum()
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %%
# checking statistical status Athletes
Athletes.describe()
# Out:
#              Name                       NOC Discipline
# count       11085                     11085      11085
# unique      11062                       206         46
# top     CHEN Yang  United States of America  Athletics
# freq            2                       615       2068

# %%
# Countries with most Praticicpant
Athletes["NOC"].value_counts().head(10)
# Out:
# United States of America      615
# Japan                         586
# Australia                     470
# People's Republic of China    401
# Germany                       400
# France                        377
# Canada                        368
# Great Britain                 366
# Italy                         356
# Spain                         324
# Name: NOC, dtype: int64

# %%
# Top 10 games from where Athletes Participated
plt.style.use("dark_background")
Athletes["Discipline"].value_counts().head(10)
top_disciplines = Athletes["Discipline"].value_counts().head(10)
top_disciplines.plot(kind='barh', color='blue',)
plt.title("Top 10 games from where Athletes Participated",color="yellow")
plt.ylabel("Games")
plt.xlabel("Number of Participants")
plt.tight_layout() # add padding
plt.show()

# %%
Athletes_count= Athletes['Name'].value_counts()
Athletes_count = Athletes_count[Athletes_count > 1]

# %%
# Total Athletes who participated in more then 1 games
Athletes_count
# Out:
# CHEN Yang                2
# KIM Hyunsoo              2
# PALTRINIERI Gregorio     2
# PORTELA Teresa           2
# KOVACS Zsofia            2
# KOPECKY Lotte            2
# ALVAREZ Jorge            2
# WELLBROCK Florian        2
# WANG Yang                2
# ZHANG Xin                2
# MARTIN Daniel            2
# LI Qian                  2
# WATANABE Yuta            2
# PEREZ Maria              2
# HALL James               2
# SUN Jiajun               2
# KURBANOV Ruslan          2
# van ROUWENDAAL Sharon    2
# HAVIK Yoeri              2
# GANNA Filippo            2
# ALI Mohamed              2
# DYGERT Chloe             2
# PEREZ Paola              2
# Name: Name, dtype: int64

# %%
len(Athletes_count)
# Out:
# 23

# %%
# Lets see the country with highest number of Athletes i.e American hae most Athletes from which games
Athletes_usa=Athletes[Athletes["NOC"]=="United States of America"]

# %%
Athletes_usa
# Out:
#                       Name                       NOC             Discipline
# 12           ABBOTT Monica  United States of America      Baseball/Softball
# 29         ABDIRAHMAN Abdi  United States of America              Athletics
# 98     ADEBAYO Edrice Femi  United States of America             Basketball
# 135            AGUILAR Ali  United States of America      Baseball/Softball
# 154        AHSINGER Nicole  United States of America  Trampoline Gymnastics
# ...                    ...                       ...                    ...
# 10989         ZHANG Beiwen  United States of America              Badminton
# 11004           ZHANG Lily  United States of America           Table Tennis
# 11040             ZHOU Xin  United States of America           Table Tennis
# 11052       ZIEMEK Zachery  United States of America              Athletics
# 11068   ZOLOTIC Anastasija  United States of America              Taekwondo
#
# [615 rows x 3 columns]

# %%
# Top 10 games from where Athletes Participated
plt.style.use("dark_background")

top_usa = Athletes_usa["Discipline"].value_counts().head(10)
top_usa.plot(kind='barh', color='orange',linestyle='--')
plt.title("Top 10 games from where Athletes Participated",color="yellow")
plt.ylabel("Games")
plt.xlabel("Number of Participants")
plt.tight_layout() # add padding
plt.show()

# %%
# Checking status of India
Athletes_India=Athletes[Athletes["NOC"]=="India"]
Athletes_India
# Out:
#                        Name    NOC    Discipline
# 75            ACHANTA Kamal  India  Table Tennis
# 348                    AMIT  India        Boxing
# 431             ANSHU Anshu  India     Wrestling
# 442             ANTONY Alex  India     Athletics
# 557             ASHOK Aditi  India          Golf
# ...                     ...    ...           ...
# 10173     VEERAMANI Revathi  India     Athletics
# 10199      VENKATESAN Subha  India     Athletics
# 10213        VERMA Abhishek  India      Shooting
# 10271         VINESH Vinesh  India     Wrestling
# 10746  YAHIYA Muhammed Anas  India     Athletics
#
# [117 rows x 3 columns]

# %%
# Total Players Of india
Athletes_India.shape[:1]
# Out:
# (117,)

# %%
 # top 10 Sports where india participated
Athletes_India["Discipline"].value_counts().head(10)

top_indian= Athletes_India["Discipline"].value_counts().head(10)
top_indian.plot(kind='barh', color='green')
plt.title("Top 10 games in which indian Athletes Participated",color="Yellow")
plt.ylabel("Games")
plt.xlabel("Number of Participants")
plt.tight_layout() # add padding
plt.show()

# %% [markdown]
# ## ***Coaches***

# %%
Coaches.head(10)
# Out:
#                         Name                       NOC         Discipline  \
# 0            ABDELMAGID Wael                     Egypt           Football
# 1                  ABE Junya                     Japan         Volleyball
# 2              ABE Katsuhiko                     Japan         Basketball
# 3               ADAMA Cherif             Côte d'Ivoire           Football
# 4                 AGEBA Yuya                     Japan         Volleyball
# 5  AIKMAN Siegfried Gottlieb                     Japan             Hockey
# 6              AL SAADI Kais                   Germany             Hockey
# 7              ALAMEDA Lonni                    Canada  Baseball/Softball
# 8            ALEKNO Vladimir  Islamic Republic of Iran         Volleyball
# 9            ALEKSEEV Alexey                       ROC           Handball
#
#       Event
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       Men
# 6       Men
# 7  Softball
# 8       Men
# 9     Women

# %%
Coaches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        394 non-null    object
#  1   NOC         394 non-null    object
#  2   Discipline  394 non-null    object
#  3   Event       249 non-null    object
# dtypes: object(4)
# memory usage: 12.4+ KB

# %%
Coaches.describe()
# Out:
#                          Name    NOC  Discipline Event
# count                     394    394         394   249
# unique                    381     61           9     6
# top     REQUENA PERICAS Judit  Japan  Basketball   Men
# freq                        2     35          74    94

# %%
Coaches.isnull().sum()
# Out:
# Name            0
# NOC             0
# Discipline      0
# Event         145
# dtype: int64

# %%
 # value count for each columns in coach dataset
 for i in Coaches.columns:
  print(i)
  print(Coaches[i].value_counts())
  print("/////////////////////////////////////////////////")
# Out:
# Name
# REQUENA PERICAS Judit    2
# FUJIKI Mayuko            2
# TARRES CAMPA Ana         2
# GUERRERO Rolando         2
# RETEGUI Carlos Jose      2
#                         ..
# GONZALEZ JARENO Angel    1
# GONZALEZ Anibal          1
# GOMEZ CORA Santiago      1
# GOJKOVIC Vladimir        1
# ZONDI Nkuliso            1
# Name: Name, Length: 381, dtype: int64
# /////////////////////////////////////////////////
# NOC
# Japan                       35
# United States of America    28
# Spain                       28
# Australia                   22
# Canada                      16
#                             ..
# Portugal                     1
# Belarus                      1
# Slovakia                     1
# Croatia                      1
# Liechtenstein                1
# Name: NOC, Length: 61, dtype: int64
# /////////////////////////////////////////////////
# Discipline
# Basketball           74
# Artistic Swimming    69
# Football             59
# Volleyball           45
# ...

# %%
# Filling Null vaes as 'Other' Event
Coaches["Event"].fillna("Other",inplace=True)

# %%
Coaches["Event"].isnull().sum()
# Out:
# 0

# %%
Coaches.head(10)
# Out:
#                         Name                       NOC         Discipline  \
# 0            ABDELMAGID Wael                     Egypt           Football
# 1                  ABE Junya                     Japan         Volleyball
# 2              ABE Katsuhiko                     Japan         Basketball
# 3               ADAMA Cherif             Côte d'Ivoire           Football
# 4                 AGEBA Yuya                     Japan         Volleyball
# 5  AIKMAN Siegfried Gottlieb                     Japan             Hockey
# 6              AL SAADI Kais                   Germany             Hockey
# 7              ALAMEDA Lonni                    Canada  Baseball/Softball
# 8            ALEKNO Vladimir  Islamic Republic of Iran         Volleyball
# 9            ALEKSEEV Alexey                       ROC           Handball
#
#       Event
# 0     Other
# 1     Other
# 2     Other
# 3     Other
# 4     Other
# 5       Men
# 6       Men
# 7  Softball
# 8       Men
# 9     Women

# %%
 Coaches["Event"].value_counts()
# Out:
# Other       145
# Men          94
# Women        88
# Duet         27
# Softball     20
# Team         14
# Baseball      6
# Name: Event, dtype: int64

# %%
event_counts = Coaches["Event"].value_counts()

colors = ['#a6cee3', '#fdbf6f', '#b2df8a', '#fb9a99', '#cab2d6', '#ff9896', '#8c564b']

plt.figure(figsize=(10, 8))
# Plotting the pie chart with custom colors
explode=[0.05,0,0,0,0,0,0]
plt.figure(figsize=(8, 8))
plt.pie(event_counts, labels=event_counts.index,explode=explode, shadow=True,autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Event Distribution',color="Red")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
## Countries with highest number of coaches
coach_Noc=Coaches["NOC"].value_counts().head(10)


coach_Noc.plot(kind='bar', color='blue',)
plt.title("Countries with highest number of coaches",color="Yellow")
plt.xlabel("Number of Coaches")
plt.ylabel("NOC")
plt.xticks( rotation=45, ha='right')

plt.tight_layout() # add padding
plt.show()

# %%
# top 10 sports with maximum number of coaches
max_coaches=Coaches["Discipline"].value_counts().head(10)

max_coaches.plot(kind='barh', color='red',)
plt.title("Top 10 sports with maximum number of coaches",color="yellow")
plt.ylabel("Game")
plt.xlabel("Number of Coaches")
plt.tight_layout() # add padding
plt.show()

# %%
# Let us see Indian Status about Coaches
Coaches[Coaches["NOC"]=="India"]
# Out:
#                        Name    NOC Discipline  Event
# 33   BILLAVA SURESH Ankitha  India     Hockey  Women
# 63      CLARK STEPHEN Gregg  India     Hockey    Men
# 232          MARIJNE Sjoerd  India     Hockey  Women
# 303        REID Graham John  India     Hockey    Men
# 333         SINGH Shivendra  India     Hockey    Men

# %% [markdown]
# ## ***EntriesGender Data***

# %%
EntriesGender.head(10)
# Out:
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# 3    Artistic Swimming     105     0    105
# 4            Athletics     969  1072   2041
# 5            Badminton      86    87    173
# 6    Baseball/Softball      90   144    234
# 7           Basketball     144   144    288
# 8     Beach Volleyball      48    48     96
# 9               Boxing     102   187    289

# %%
EntriesGender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Discipline  46 non-null     object
#  1   Female      46 non-null     int64
#  2   Male        46 non-null     int64
#  3   Total       46 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB

# %%
EntriesGender.shape
# Out:
# (46, 4)

# %%
EntriesGender.describe()
# Out:
#            Female         Male       Total
# count   46.000000    46.000000    46.00000
# mean   118.086957   127.913043   246.00000
# std    147.169717   166.900746   312.46134
# min     10.000000     0.000000    19.00000
# 25%     42.750000    40.250000    85.50000
# 50%     90.000000    97.500000   190.00000
# 75%    138.750000   149.750000   288.75000
# max    969.000000  1072.000000  2041.00000

# %%
EntriesGender.isnull().sum()
# Out:
# Discipline    0
# Female        0
# Male          0
# Total         0
# dtype: int64

# %%
for i in EntriesGender.columns:
  print(i)
  print(EntriesGender[i].value_counts())
  print("////////////////////////////////")
# Out:
# Discipline
# 3x3 Basketball           1
# Sport Climbing           1
# Karate                   1
# Marathon Swimming        1
# Modern Pentathlon        1
# Rhythmic Gymnastics      1
# Rowing                   1
# Rugby Sevens             1
# Sailing                  1
# Shooting                 1
# Skateboarding            1
# Surfing                  1
# Archery                  1
# Swimming                 1
# Table Tennis             1
# Taekwondo                1
# Tennis                   1
# Trampoline Gymnastics    1
# Triathlon                1
# Volleyball               1
# Water Polo               1
# Weightlifting            1
# Judo                     1
# Hockey                   1
# Handball                 1
# Golf                     1
# Artistic Gymnastics      1
# Artistic Swimming        1
# Athletics                1
# Badminton                1
# Baseball/Softball        1
# Basketball               1
# Beach Volleyball         1
# Boxing                   1
# ...

# %%
## checking if sum of male and female is equal to total or any error in data
count=0
for i in range(0,46):
  if EntriesGender.Male[i]+EntriesGender.Female[i]!=EntriesGender.Total[i]:
    count+=1
print(count)
# Out:
# 0

# %%
# Sports with maximum number of Entries
EntriesGender_sort=EntriesGender.sort_values(by='Total', ascending=False)
max_entries=EntriesGender_sort.iloc[:,[0,3]].head(10)
max_entries.plot(kind='barh',color="green")
plt.title("Sports with maximum number of Entries",color="Yellow")
plt.xlabel("Discipline")
plt.ylabel("Total")
plt.show()

# %%
# Sports with top 10 sports with female entries
EntriesGender_sort=EntriesGender.sort_values(by='Female', ascending=False)
top_female=EntriesGender_sort.iloc[:,[0,1]].head(10)

# %%
# Sports with top 10 sports with  male entries
EntriesGender_sort=EntriesGender.sort_values(by='Male', ascending=False)
top_male=EntriesGender_sort.iloc[:,[0,2]].head(10)

# %%
## Sports where male Entries are more then Female Entries
Higher_Male_Entries=EntriesGender[EntriesGender["Female"]<EntriesGender["Male"]].sort_values(by="Male",ascending=False).iloc[:,[0,1,2]]


## double bar
bar_width = 0.35
index = range(len(Higher_Male_Entries))

plt.bar(index, Higher_Male_Entries['Female'], width=bar_width, label='Female', color='skyblue')
plt.bar([i + bar_width for i in index], Higher_Male_Entries['Male'], width=bar_width, label='Male', color='orange')

plt.xlabel('Discipline')
plt.ylabel('Number of Entries')
plt.title('Number of Entries by Discipline and Gender')
plt.xticks([i + bar_width / 2 for i in index], Higher_Male_Entries['Discipline'], rotation=45, ha='right')
plt.legend()

plt.show()

# %%
## Sports where Female Entries are more then Female Entries
Higher_Female_Entries=EntriesGender[EntriesGender["Female"]>EntriesGender["Male"]].sort_values(by="Female",ascending=False).iloc[:,[0,1,2]]



bar_width = 0.35
index = range(len(Higher_Female_Entries))

plt.bar(index, Higher_Female_Entries['Female'], width=bar_width, label='Female', color='skyblue')
plt.bar([i + bar_width for i in index], Higher_Female_Entries['Male'], width=bar_width, label='Male', color='green')

plt.xlabel('Discipline')
plt.ylabel('Number of Entries')
plt.title('Number of Entries by Discipline and Gender')
plt.xticks([i + bar_width / 2 for i in index], Higher_Female_Entries['Discipline'], rotation=45, ha='right')
plt.legend()

plt.show()

# %% [markdown]
# ## ***Medals data***

# %%
Medals.head(10)
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
# 5     6                   Australia    17       7      22     46
# 6     7                 Netherlands    10      12      14     36
# 7     8                      France    10      12      11     33
# 8     9                     Germany    10      11      16     37
# 9    10                       Italy    10      10      20     40
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3
# 5              6
# 6              9
# 7             10
# 8              8
# 9              7

# %%
Medals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           93 non-null     int64
#  1   Team/NOC       93 non-null     object
#  2   Gold           93 non-null     int64
#  3   Silver         93 non-null     int64
#  4   Bronze         93 non-null     int64
#  5   Total          93 non-null     int64
#  6   Rank by Total  93 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
Medals.shape
# Out:
# (93, 7)

# %%
Medals.isnull().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold             0
# Silver           0
# Bronze           0
# Total            0
# Rank by Total    0
# dtype: int64

# %%
# Checking if data is correct
count=0
for i in range(0,93):
  if Medals.Gold[i]+Medals.Silver[i]+Medals.Bronze[i]!=Medals.Total[i]:
    count+=1
print(count)
# Out:
# 0

# %%
## Indian Medal Status
Medals[Medals["Team/NOC"]=="India"]
# Out:
#     Rank Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 47    48    India     1       2       4      7             33
